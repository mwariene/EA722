# %% [markdown]
# ### Experiência 2 - Emulador Industrial

# %% [markdown]
# #### Sem perturbação

# %%
kp = 0.12

# %%
kp = 0.18

# %%
kp = 0.24

# %% [markdown]
# #### Com perturbação

# %%
kp = 0.12

# %%
kp = 0.18

# %%
kp = 0.24
